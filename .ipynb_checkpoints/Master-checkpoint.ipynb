# %% [markdown]
# # Ballot Measures Funding Local Government
# This data set shows the success rate of local government funding measures across the state of Wahsington from 2011-2017. The goal of this research is to find patterns in what voters are willing to approove to expand local government in light of property tax caps in state law.

# %% [markdown]
# ## Descriptive Statistics
# Before any analysis is possible, we have to understand the general patterns in the data.

# %%
import pandas as pd

# %%
data= 'https://github.com/nbennett4025/govproject/raw/master/ballotinitiativesWA.xlsx'

# %%
ballot=pd.read_excel(data,0)
ballot.dtypes
# Out:
# Jurisdiction                         object
# County                               object
# Government Type                      object
# Subject                              object
# Ballot Measure Text                  object
# Election Results                     object
# Yes %                               float64
# No %                                float64
# Election Month                       object
# Election Year                         int64
# Duration in Years Levy/Fee           object
# Amount of Levy (Per $1000 A/V)      float64
# Tax Amount                          float64
# Bond Amount                         float64
# Funding Type/Statutory Authority     object
# dtype: object

# %%
ballotyes=ballot['Yes %']

# %% [markdown]
# To understand the data it is important to know that it takes a majority vote to raise taxes in a district. As the table below shows, less than 25% of measures fail.

# %%
ballotyes.describe()
# Out:
# count    1434.000000
# mean       62.784426
# std        14.206475
# min         0.000000
# 25%        54.750000
# 50%        64.575000
# 75%        72.442500
# max       100.000000
# Name: Yes %, dtype: float64

# %% [markdown]
# The data appear to be fairly normal, which makes them a good candidate for most statistical analysis.

# %%
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(ballotyes.dropna(),kde=False,fit=norm)
plt.legend(('data fit to normal','data as it is'))
plt.title('How often do funding measures get 50% in WA?')
plt.show()

# %%
plot,dataBP=ballotyes.plot.box(vert=False,return_type='both')
plt.title('Distribution of Ballot Measure Approval Rates 2011-2017')
plt.show()
#looks like the data have a longer left tail, but are generally close to being 
#'normal'. On average it seems like things get the required 60% about
# a little more than half of the time

# %%
#Moving on to bi-variate analysis
from scipy import stats

# %% [markdown]
# ## Breakdown by government type, timing, and Subject
# There are a lot of different governments captured within the data. To facilitate analysis we can simplify the large number of categories into three big ones: cities, counties, and various special purpose governments. Counties, which proivde both regional and local services, have the most difficult time getting funding approved.

# %%
ballot['Government Type'].value_counts()
# Out:
# City                                      481
# Fire Protection District                  425
# Park District                             161
# County                                    110
# Cemetery District                          60
# Public Hospital District                   58
# Transportation Benefit District            40
# Port District                              20
# Emergency Medical Services District        16
# Water-Sewer District                       14
# Public Transportation Benefit Area         13
# Library District                           13
# Public Facilities District                  7
# Solid Waste Disposal District               6
# Mosquito Control District                   4
# County Public Transportation Authority      2
# Public Utility District                     2
# Flood Control Zone District                 1
# Regional Transit Authority                  1
# Name: Government Type, dtype: int64

# %%
values = list(ballot['Government Type'].value_counts().index)
values
# Out:
# ['City',
#  'Fire Protection District',
#  'Park District',
#  'County',
#  'Cemetery District',
#  'Public Hospital District',
#  'Transportation Benefit District',
#  'Port District',
#  'Emergency Medical Services District',
#  'Water-Sewer District',
#  'Public Transportation Benefit Area',
#  'Library District',
#  'Public Facilities District',
#  'Solid Waste Disposal District',
#  'Mosquito Control District',
#  'County Public Transportation Authority',
#  'Public Utility District',
#  'Flood Control Zone District',
#  'Regional Transit Authority']

# %%
city = values[0]
county = values[3]
govsimple = []

for value in ballot['Government Type']:
    if value in city:
        govsimple.append('City')
    else:
        if value in county:
            govsimple.append('County')
        else:
            govsimple.append('Special District')

# %%
ballot['govsimple'] = govsimple

# %%
sns.factorplot(x='govsimple', y= 'Yes %', data=ballot)
plt.title('Approval Rate by Government Type')
plt.show()

# %% [markdown]
# For election timing it seems that any non-November election is more likely to yield positive results. The year seems not to yield any predictable pattern.

# %%
# it would seem that counties have a harder time passing funding than cities
# or special districts
#Does the month of the election matter?
sns.factorplot(x='Election Month', y= 'Yes %', data=ballot, size=5)
plt.title('Approval Rate by Election Month')
plt.show()

# %%
sns.factorplot(x='Election Year', y= 'Yes %', data=ballot)
plt.title('By Election Year')
plt.show()
#looks like 2011 was a bad year for funding

# %%
#looking a little closer
ballot['Election Year'].value_counts()
# Out:
# 2016    252
# 2015    247
# 2017    213
# 2013    211
# 2012    205
# 2014    195
# 2011    111
# Name: Election Year, dtype: int64

# %% [markdown]
# Like government type, subject matter of the ballot measure needs to be simplified.

# %%
import numpy as np
subjects = list(ballot['Subject'].value_counts().index)
subjects
# Out:
# ['EMS',
#  'Parks and Recreation',
#  'Fire',
#  'Transportation',
#  'Other',
#  'Government Organization',
#  'Fire, EMS',
#  'Cemetery',
#  'Criminal Justice',
#  'Hospital',
#  'Annexation, Fire',
#  'Library',
#  'Water and Sewer',
#  'Annexation',
#  'Criminal Justice, Fire',
#  'Annexation, Library',
#  'Transportation, Water and Sewer, Other',
#  'Government Organization, Fire',
#  'Affordable Housing',
#  'Criminal Justice, Other',
#  'Transportation, Criminal Justice',
#  'Annexation, Transportation',
#  'Parks and Recreation, Other',
#  'Fire, Other',
#  'Fire, EMS, Criminal Justice',
#  'Criminal Justice, Fire, Parks and Recreation, Other',
#  'Human Services',
#  'Transportation, Parks and Recreation',
#  'Criminal Justice, Parks and Recreation, Other',
#  'Criminal Justice, Parks and Recreation',
#  'Annexation, Water-Sewer',
#  'Criminal Justice, Fire, Parks and Recreation, Transportation, Other',
#  'Government Organization, Other',
#  'Government Organization, Criminal Justice',
#  'Criminal Justice, Library, Parks and Recreation',
#  'Criminal Justice, Library, Parks and Recreation, Other',
#  'Fire, Parks and Recreation, Other',
#  'Government Organization, Parks and Recreation',
#  'Criminal Justice, Human Services',
#  'Fire, EMS, Transportation, Parks and Recreation, Criminal Justice',
#  'Transportation, Other',
#  'Fire, EMS, Transportation, Criminal Justice, Other']

# %%
parks = subjects[1]
transit = subjects[3]
govorg =subjects[5]
cemetery=subjects[7]
other=subjects[4]
water=subjects[12]
publicsafety = ['EMS', 'Fire', 'Fire, EMS', 'Criminal Justice']
human = ['Hospital', 'Library', 'Affordable Housing', 'Human Services']
annexation = ['Annexation, Fire', 'Annexation', 'Annexation, Library', 'Annexation, Transportation', 'Annexation, Water-Sewer']

# %%
parks
# Out:
# 'Parks and Recreation'

# %%
subsimple = []
for value in ballot['Subject']:
    if value in parks:
        subsimple.append('Parks')
    else:
        if value in transit:
            subsimple.append('Transit')
        else:
            if value in govorg:
                subsimple.append('Government Organization')
            else: 
                if value in cemetery:
                    subsimple.append('Cemetery')
                else:
                    if value in water:
                        subsimple.append('Water/Sewer')
                    else:
                        if value in other:
                            subsimple.append('Other')
                        else:
                            if value in publicsafety:
                                subsimple.append('Public Safety')
                            else:
                                if value in human:
                                    subsimple.append('Human Services')
                                else:
                                    if value in annexation:
                                        subsimple.append('Annexation')
                                    else:
                                        subsimple.append('Multiple')

# %%
ballot['subsimple'] = subsimple

# %%
sns.factorplot(x='subsimple', y= 'Yes %', data=ballot,size=7, aspect=2)
plt.title('By subject matter')
plt.show()

# %% [markdown]
# Based on the chart we can see fairly large variations in how different subjects fare on the ballot. In general local services like a cemetaries, water/sewer, and public safety do well. Regional services like transit and government itself are less likely to do well. Annexation is tricky, becuase unlike other issues covered here it requires a larger than 50% margin to pass. As a consequence annexations are much less likely to pass even though they have a higher average yes %.

# %% [markdown]
# ## Correlation and Regression Analysis
# Based on descripttive statistics that we walked through in the previous section it would seem to be a good candidate for regression analysis to see if any of the factors have a significant impact on the outcome. To begin we need to make sure that our explanatory variables are not correlated.

# %%
#time for some correlations
ballot.dtypes
# Out:
# Jurisdiction                         object
# County                               object
# Government Type                      object
# Subject                              object
# Ballot Measure Text                  object
# Election Results                     object
# Yes %                               float64
# No %                                float64
# Election Month                       object
# Election Year                         int64
# Duration in Years Levy/Fee           object
# Amount of Levy (Per $1000 A/V)      float64
# Tax Amount                          float64
# Bond Amount                         float64
# Funding Type/Statutory Authority     object
# govsimple                            object
# subsimple                            object
# dtype: object

# %%
yes = ballot['Yes %']
no = ballot['No %']
duration = ballot['Duration in Years Levy/Fee']
levy = ballot['Amount of Levy (Per $1000 A/V)']
tax = ballot['Tax Amount']
bond = ballot['Bond Amount']

# %%
data={'yes':yes, 'no':no, 'duration':duration, 'levy':levy, 'tax':tax, 'bond':bond}

# %%
ballotcorr = pd.DataFrame.from_dict(data)

# %%
#looks like duration is going to be a problem so lets drop it as a variable
ballotcorr.drop('duration',axis=1,inplace=True)

# %%
ballotcorr.corr('pearson', 1)
# Out:
#           bond      levy        no       tax       yes
# bond  1.000000       NaN -0.075546       NaN  0.075543
# levy       NaN  1.000000  0.141061 -1.000000 -0.137931
# no   -0.075546  0.141061  1.000000 -0.254060 -0.979699
# tax        NaN -1.000000 -0.254060  1.000000  0.254068
# yes   0.075543 -0.137931 -0.979699  0.254068  1.000000

# %% [markdown]
# Based on this table it looks like none of the numeric variables are correlated with one another except % yes and % no, which we would expect. We can also see this relationship visually.

# %%
pd.plotting.scatter_matrix(ballotcorr,figsize=(12,12))
plt.show()

# %%
# alright it looks like only certain types of funding respond at all to the amount being asked for

# %%
#in order to have a good regression we need to turn some variables into dummy variables

# %%
ballot['Subject'].value_counts()
# Out:
# EMS                                                                    214
# Parks and Recreation                                                   200
# Fire                                                                   190
# Transportation                                                         134
# Other                                                                  117
# Government Organization                                                115
# Fire, EMS                                                              114
# Cemetery                                                                60
# Criminal Justice                                                        55
# Hospital                                                                44
# Annexation, Fire                                                        32
# Library                                                                 32
# Water and Sewer                                                         23
# Annexation                                                              18
# Criminal Justice, Fire                                                  15
# Annexation, Library                                                      9
# Transportation, Water and Sewer, Other                                   7
# Government Organization, Fire                                            6
# Affordable Housing                                                       5
# Criminal Justice, Other                                                  4
# Transportation, Criminal Justice                                         4
# Annexation, Transportation                                               4
# Parks and Recreation, Other                                              3
# Fire, Other                                                              3
# Fire, EMS, Criminal Justice                                              3
# Criminal Justice, Fire, Parks and Recreation, Other                      3
# Human Services                                                           3
# Transportation, Parks and Recreation                                     2
# Criminal Justice, Parks and Recreation, Other                            2
# Criminal Justice, Parks and Recreation                                   1
# Annexation, Water-Sewer                                                  1
# Criminal Justice, Fire, Parks and Recreation, Transportation, Other      1
# Government Organization, Other                                           1
# Government Organization, Criminal Justice                                1
# Criminal Justice, Library, Parks and Recreation                          1
# Criminal Justice, Library, Parks and Recreation, Other                   1
# Fire, Parks and Recreation, Other                                        1
# Government Organization, Parks and Recreation                            1
# Criminal Justice, Human Services                                         1
# Fire, EMS, Transportation, Parks and Recreation, Criminal Justice        1
# Transportation, Other                                                    1
# Fire, EMS, Transportation, Criminal Justice, Other                       1
# Name: Subject, dtype: int64

# %%
ballot['subsimple'].value_counts()
# Out:
# Public Safety              573
# Parks                      200
# Transit                    134
# Other                      117
# Government Organization    115
# Human Services              84
# Annexation                  64
# Multiple                    64
# Cemetery                    60
# Water/Sewer                 23
# Name: subsimple, dtype: int64

# %%
#dummy recodes
#1 - election month
months = list(ballot['Election Month'].value_counts().index)
months
# Out:
# ['November', 'August', 'February', 'April', 'NOVEMBER']

# %%
november = months[0]
august = months[1]
february = months[2]
april = months[3]
novembercap = months[4]

isnovember = []
for value in ballot['Election Month']:
    if value in november or novembercap:
        isnovember.append(1)
    else:
        isnovember.append(0)

ballot['isnovember'] = isnovember

isaugust =[]
for value in ballot['Election Month']:
    if value in august:
        isaugust.append(1)
    else:
        isaugust.append(0)

ballot['isaugust'] = isaugust

isfebruary =[]
for value in ballot['Election Month']:
    if value in february:
        isfebruary.append(1)
    else:
        isfebruary.append(0)

ballot['isfebruary'] = isfebruary

isapril =[]
for value in ballot['Election Month']:
    if value in april:
        isapril.append(1)
    else:
        isapril.append(0)

ballot['isapril'] = isapril

# %%
#recoding election results as a dummy variable
result = list(ballot['Election Results'].value_counts().index)
result
# Out:
# ['Passed', 'Failed', 'Advisory']

# %%
passing=result[0]
failing=result[1]
passed=[]
for value in ballot['Election Results']:
    if value in passing:
        passed.append(1)
    else:
        if value in failing:
            passed.append(0)
        else:
            passed.append(None)
            
ballot['passed']=passed

# %%
ballot['levy']=ballot['Amount of Levy (Per $1000 A/V)']
ballot['salestax'] = ballot['Tax Amount']
ballot['bondamt'] = ballot['Bond Amount']

# %%
ballot.dtypes
# Out:
# Jurisdiction                         object
# County                               object
# Government Type                      object
# Subject                              object
# Ballot Measure Text                  object
# Election Results                     object
# Yes %                               float64
# No %                                float64
# Election Month                       object
# Election Year                         int64
# Duration in Years Levy/Fee           object
# Amount of Levy (Per $1000 A/V)      float64
# Tax Amount                          float64
# Bond Amount                         float64
# Funding Type/Statutory Authority     object
# govsimple                            object
# subsimple                            object
# isnovember                            int64
# isaugust                              int64
# isfebruary                            int64
# isapril                               int64
# passed                              float64
# levy                                float64
# salestax                            float64
# bondamt                             float64
# dtype: object

# %%
#now that the relavent variables are ready lets see if the x's are correlated
xvars = ballot.columns[[19,20,21,22,23,24]]
ballot[xvars].corr()
# Out:
#             isfebruary   isapril    passed      levy  salestax   bondamt
# isfebruary    1.000000 -0.084309  0.069492  0.036321 -0.046923 -0.081322
# isapril      -0.084309  1.000000  0.034492 -0.071166  0.367510  0.117694
# passed        0.069492  0.034492  1.000000 -0.061768  0.079036  0.052004
# levy          0.036321 -0.071166 -0.061768  1.000000 -1.000000       NaN
# salestax     -0.046923  0.367510  0.079036 -1.000000  1.000000       NaN
# bondamt      -0.081322  0.117694  0.052004       NaN       NaN  1.000000

# %% [markdown]
# ### Regression Models
# Becuase each ballot issue can only have one of the funding types there are three different models tested: one for property tax levys, one for sales tax increases, and one for debt issuance authority.
#
# Each of the models regressess whether or not an initiative passed on the amount of the tax increase or debt authority, the subject of the initiative, the type of government it would fund and the timing of the election. The ommitted categories are Annexation, cities, and November elections respectively.

# %%
#looks like we are in the clear, lets run the regression on 'passed'
import statsmodels.formula.api as smf
formulalevy='passed ~ levy + isaugust + isfebruary + isapril + subsimple + govsimple'
levylogit = smf.ols(formulalevy,data=ballot).fit()
print(levylogit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 passed   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     4.740
# Date:                Thu, 15 Mar 2018   Prob (F-statistic):           1.97e-08
# Time:                        11:15:22   Log-Likelihood:                -392.98
# No. Observations:                 887   AIC:                             816.0
# Df Residuals:                     872   BIC:                             887.8
# Df Model:                          14
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.7548      0.049     15.293      0.000       0.658       0.852
# subsimple[T.Cemetery]                    0.1739      0.063      2.758      0.006       0.050       0.298
# subsimple[T.Government Organization]     0.3163      0.343      0.922      0.357      -0.357       0.989
# subsimple[T.Human Services]             -0.0546      0.062     -0.879      0.380      -0.177       0.067
# subsimple[T.Multiple]                    0.0177      0.076      0.234      0.815      -0.131       0.167
# subsimple[T.Other]                      -0.1079      0.067     -1.601      0.110      -0.240       0.024
# subsimple[T.Parks]                       0.0682      0.051      1.333      0.183      -0.032       0.169
# subsimple[T.Public Safety]               0.0950      0.045      2.106      0.035       0.006       0.183
# subsimple[T.Transit]                     0.0050      0.063      0.080      0.936      -0.119       0.129
# subsimple[T.Water/Sewer]                 0.2412      0.089      2.706      0.007       0.066       0.416
# govsimple[T.County]                     -0.1389      0.087     -1.596      0.111      -0.310       0.032
# govsimple[T.Special District]           -0.0491      0.034     -1.429      0.153      -0.117       0.018
# levy                                    -0.0441      0.022     -2.039      0.042      -0.087      -0.002
# isaugust                                 0.1138      0.030      3.838      0.000       0.056       0.172
# isfebruary                               0.2099      0.050      4.197      0.000       0.112       0.308
# isapril                                  0.1939      0.059      3.272      0.001       0.078       0.310
# ==============================================================================
# Omnibus:                      183.504   Durbin-Watson:                   1.547
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.182
# Skew:                          -1.427   Prob(JB):                     7.28e-68
# Kurtosis:                       3.464   Cond. No.                     1.67e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.7e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import statsmodels.formula.api as smf
formulasales='passed ~ salestax + isaugust + isfebruary + isapril + subsimple + govsimple'
saleslogit = smf.ols(formulasales,data=ballot).fit()
print(saleslogit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 passed   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.148
# Date:                Thu, 15 Mar 2018   Prob (F-statistic):              0.330
# Time:                        11:15:22   Log-Likelihood:                -72.679
# No. Observations:                 124   AIC:                             171.4
# Df Residuals:                     111   BIC:                             208.0
# Df Model:                          12
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.4039      0.275      1.470      0.144      -0.140       0.948
# subsimple[T.Cemetery]                -7.879e-16   6.84e-16     -1.153      0.252   -2.14e-15    5.67e-16
# subsimple[T.Government Organization]  7.104e-16    5.3e-16      1.340      0.183    -3.4e-16    1.76e-15
# subsimple[T.Human Services]              0.5954      0.535      1.112      0.269      -0.466       1.656
# subsimple[T.Multiple]                    0.1889      0.294      0.643      0.522      -0.393       0.771
# subsimple[T.Other]                      -0.0574      0.295     -0.195      0.846      -0.642       0.527
# subsimple[T.Parks]                       0.1595      0.358      0.446      0.657      -0.550       0.869
# subsimple[T.Public Safety]               0.1284      0.284      0.452      0.652      -0.434       0.691
# subsimple[T.Transit]                     0.2906      0.241      1.207      0.230      -0.186       0.768
# subsimple[T.Water/Sewer]              2.487e-16    2.1e-16      1.185      0.239   -1.67e-16    6.65e-16
# govsimple[T.County]                      0.2136      0.135      1.577      0.118      -0.055       0.482
# govsimple[T.Special District]            0.0328      0.147      0.223      0.824      -0.258       0.324
# salestax                                 0.6644      0.764      0.869      0.387      -0.850       2.179
# isaugust                                -0.0609      0.115     -0.530      0.597      -0.289       0.167
# isfebruary                               0.3034      0.171      1.774      0.079      -0.035       0.642
# isapril                                  0.1173      0.138      0.852      0.396      -0.155       0.390
# ==============================================================================
# Omnibus:                       39.648   Durbin-Watson:                   1.673
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.202
# Skew:                          -0.689   Prob(JB):                     0.000303
# Kurtosis:                       1.888   Cond. No.                     7.82e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.54e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import statsmodels.formula.api as smf
formulabond='passed ~ bondamt + isaugust + isfebruary + isapril + subsimple + govsimple'
bondlogit = smf.ols(formulabond,data=ballot).fit()
print(bondlogit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 passed   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     1.344
# Date:                Thu, 15 Mar 2018   Prob (F-statistic):              0.219
# Time:                        11:15:22   Log-Likelihood:                -64.042
# No. Observations:                 101   AIC:                             150.1
# Df Residuals:                      90   BIC:                             178.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.3978      0.094      4.226      0.000       0.211       0.585
# subsimple[T.Cemetery]                -2.169e-09   7.47e-10     -2.903      0.005   -3.65e-09   -6.85e-10
# subsimple[T.Government Organization]  9.345e-17   6.49e-17      1.440      0.153   -3.55e-17    2.22e-16
# subsimple[T.Human Services]             -0.0261      0.143     -0.182      0.856      -0.310       0.258
# subsimple[T.Multiple]                    0.3509      0.199      1.762      0.081      -0.045       0.747
# subsimple[T.Other]                      -0.1872      0.275     -0.681      0.498      -0.733       0.359
# subsimple[T.Parks]                       0.0580      0.108      0.538      0.592      -0.156       0.272
# subsimple[T.Public Safety]               0.2386      0.114      2.094      0.039       0.012       0.465
# subsimple[T.Transit]                    -0.0364      0.195     -0.187      0.852      -0.424       0.351
# subsimple[T.Water/Sewer]             -3.328e-17    3.4e-17     -0.979      0.330   -1.01e-16    3.42e-17
# govsimple[T.County]                  -1.166e-18   1.16e-17     -0.100      0.920   -2.43e-17    2.19e-17
# govsimple[T.Special District]            0.0845      0.127      0.666      0.507      -0.168       0.337
# bondamt                               1.688e-09   1.52e-09      1.111      0.269   -1.33e-09    4.71e-09
# isaugust                                -0.1399      0.131     -1.065      0.290      -0.401       0.121
# isfebruary                               0.1789      0.161      1.112      0.269      -0.141       0.499
# isapril                                  0.0158      0.144      0.110      0.913      -0.271       0.302
# ==============================================================================
# Omnibus:                       88.019   Durbin-Watson:                   2.316
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               10.252
# Skew:                          -0.369   Prob(JB):                      0.00594
# Kurtosis:                       1.624   Cond. No.                     2.51e+25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.5e-34. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# As we can see from the results none of these models does a good job of explaining funding results. The strongest, for increases in property taxes, only explains about 5% of the variation in the passage of property tax increases.  With such a low r-squared it is difficult to read much into the results.
#
# ## Mapping Funding Failures
# If the amount, subject, government type, and timing of elections dont explain variations in passage then we may turn to spatial information to find patterns in the data.

# %%
import geopandas as gpd

# %%
#to download this shp file go to https://github.com/nbennett4025/Data/blob/master/WAOFM.zip
compressedmap = 'C:/Users/benne/Desktop/govproject/govproject/shape.shp'

# %%
countymap =gpd.GeoDataFrame.from_file(compressedmap)

# %%
countymap.head()
# Out:
#   countyfp     name                                           geometry
# 0      001    Adams  POLYGON ((-118.9825480580862 46.91134733328905...
# 1      003   Asotin  POLYGON ((-117.4196632992044 46.27754321148509...
# 2      005   Benton  POLYGON ((-119.8654444991138 46.12714840917387...
# 3      007   Chelan  POLYGON ((-120.9464421249536 47.47252236561713...
# 4      009  Clallam  POLYGON ((-123.5206495706549 48.22911230114539...

# %%
#Ensuring that the merge category is the same data type
countymap.name.dtype
# Out:
# dtype('O')

# %%
ballot.County.dtype
# Out:
# dtype('O')

# %%
#Lets merge these data!
mergedmap=countymap.merge(ballot, left_on='name', right_on='County')
mergedmap
# Out:
#      countyfp     name                                           geometry  \
# 0         001    Adams  POLYGON ((-118.9825480580862 46.91134733328905...
# 1         001    Adams  POLYGON ((-118.9825480580862 46.91134733328905...
# 2         001    Adams  POLYGON ((-118.9825480580862 46.91134733328905...
# 3         001    Adams  POLYGON ((-118.9825480580862 46.91134733328905...
# 4         001    Adams  POLYGON ((-118.9825480580862 46.91134733328905...
# 5         001    Adams  POLYGON ((-118.9825480580862 46.91134733328905...
# 0     Excess levy ($0.21) for cemetery maintenance a...           Passed
# 1     Excess levy ($0.27) for cemetery maintenance a...           Passed
# 2     Excess levy ($0.27) for cemetery maintenance a...           Passed
# 3     Excess levy ($0.19) for cemetery maintenance a...           Passed
# 4     Excess levy ($0.26) for cemetery maintenance a...           Passed
# 5     Excess levy ($0.26) for cemetery maintenance a...           Passed
# 6     Excess levy ($0.02) for cemetery maintenance a...           Failed
# 7     Excess levy ($0.02) for cemetery maintenance a...           Failed
# 8     Excess levy ($0.11) for cemetery maintenance a...           Failed
# 9     Excess levy ($0.12) for cemetery maintenance a...           Passed
# 10    Excess levy ($0.12) for cemetery maintenance a...           Passed
# 11    Excess levy ($0.12) for cemetery maintenance a...           Passed
# 12    Excess levy ($0.15) for cemetery maintenance a...           Passed
# 13    Excess levy ($0.16) for cemetery maintenance a...           Passed
# 14    Fire district excess levy (1 year, $0.66) for ...           Passed
# 15    Excess levy ($1.35) for construction, maintena...           Passed
# 16    Fire district excess levy (1 year, $1.35) for ...           Passed
# 17    Fire district excess levy (1 year, $1.35) for ...           Passed
# 18    Excess fire district levy (1 year, $1.35) for ...           Passed
# 19    Excess fire district levy (1 year, $1.35) for ...           Passed
# 20    Fire district excess levy (2 years, $0.43) for...           Passed
# 21    Fire district excess levy (2 years, $0.47) for...           Passed
# 22    Excess levy ($0.73) for swimming pool maintena...           Passed
# 23    Excess levy ($1.08) for swimming pool maintena...           Passed
# 24    Excess levy ($1.11) for maintenance and operat...           Failed
# 25    Excess levy ($0.24) for swimming pool maintena...           Passed
# 26    Excess levy ($0.24) for swimming pool maintena...           Passed
# 27    Excess levy ($0.25) for swimming pool maintena...           Passed
# 28    Excess levy ($0.24) for swimming pool maintena...           Passed
# 29    Excess levy ($0.25) for swimming pool maintena...           Passed
# ...                                                 ...              ...
# 1353                 EMS levy renewal (6 years, $0.50).           Passed
# 1354                        Permanent EMS levy ($0.50).           Passed
# 1355     EMS levy, initial imposition (6 years, $0.50).           Failed
# 1356  Fire district excess levy (4 years, $0.53) for...           Passed
# 1357  Fire district excess levy (4 years, $0.62) for...           Passed
# 1358                 EMS levy renewal (6 years, $0.47).           Passed
# 1359                                                NaN           Passed
# 1360  Single-year levy lid lift (to $0.50, permanent...           Passed
# 1361  Single-year levy lid lift (to $0.50, permanent...           Passed
# 1362  Excess levy (2 years, $0.62) for park district...           Passed
# 1363  Excess levy ($0.60) for general operations and...           Passed
# 1364  Excess levy ($0.60) for general operations and...           Failed
# 1365  Excess levy ($0.58) for park district operatin...           Passed
# 1366  Excess levy ($0.20) for swimming pool operations.           Failed
# 1367  Bonds (20 years, $6.2 million) for new and imp...           Passed
# 1368  Park and recreation service area regular levy ...           Passed
# 1369  Bonds (20 years, $5.3 million) for renovating ...           Passed
# 1370  Changing form of government from mayor-council...           Passed
# 1371  City charter amendment creating a dedicated pa...           Passed
# 1372  City charter amendment requiring at least 5 co...           Passed
# 1373  City charter amendment creating a dedicated st...           Passed
# 1374  Advisory vote on whether the county should con...         Advisory
# 1375  Public safety sales tax (0.3%) for public safe...           Passed
# 1376  Juvenile detention and jail sales tax (10 year...           Failed
# 1377                EMS levy renewal (10 years, $0.25).           Passed
# 1378  Establishing a board of freeholders to frame a...           Failed
# 1379  Multi-year levy lid lift (to $1.00, 6 years/pe...           Passed
# 1380  Bonds (20 years, $2.2 million) to replace and ...           Passed
# 1381  Multi-year levy lid lift (to $1.00, 6 years/pe...           Passed
# 1382  Single-year levy lid lift (to $1.00, permanent...           Passed
#
#        Yes %    ...             govsimple                subsimple  \
# 0      76.84    ...      Special District                 Cemetery
# 1      70.97    ...      Special District                 Cemetery
# 2      85.22    ...      Special District                 Cemetery
# 3      81.82    ...      Special District                 Cemetery
# 4      85.94    ...      Special District                 Cemetery
# 5      84.70    ...      Special District                 Cemetery
# 6      63.52    ...      Special District                 Cemetery
# 7      50.86    ...      Special District                 Cemetery
# 8      57.62    ...      Special District                 Cemetery
# 9      61.12    ...      Special District                 Cemetery
# 10     61.51    ...      Special District                 Cemetery
# 11     67.06    ...      Special District                 Cemetery
# 12     65.91    ...      Special District                 Cemetery
# 13     64.97    ...      Special District                 Cemetery
# 14    100.00    ...      Special District            Public Safety
# 15     72.73    ...      Special District            Public Safety
# 16    100.00    ...      Special District            Public Safety
# 17    100.00    ...      Special District            Public Safety
# 18    100.00    ...      Special District            Public Safety
# 19    100.00    ...      Special District            Public Safety
# 20     96.08    ...      Special District            Public Safety
# 21     89.29    ...      Special District            Public Safety
# 22     61.48    ...      Special District                    Parks
# 23     68.50    ...      Special District                    Parks
# 24     56.76    ...      Special District                    Parks
# 25     69.35    ...      Special District                    Parks
# 26     64.59    ...      Special District                    Parks
# 27     73.57    ...      Special District                    Parks
# 28     66.09    ...      Special District                    Parks
# 29     70.85    ...      Special District                    Parks
# ...      ...    ...                   ...                      ...
# 1353   90.43    ...      Special District            Public Safety
# 1354   74.03    ...      Special District            Public Safety
# 1355   55.60    ...      Special District            Public Safety
# 1356   87.78    ...      Special District            Public Safety
# 1357   77.03    ...      Special District            Public Safety
# 1358   76.59    ...      Special District            Public Safety
# 1359   61.19    ...      Special District           Human Services
# 1360   58.91    ...      Special District           Human Services
# 1361   58.16    ...      Special District           Human Services
# 1362   67.69    ...      Special District                    Parks
# 1363   73.33    ...      Special District                    Parks
# 1364   59.71    ...      Special District                    Parks
# 1365   62.54    ...      Special District                    Parks
# 1366   55.85    ...      Special District                    Parks
# 1367   66.50    ...      Special District                    Parks
# 1368   78.56    ...      Special District                    Parks
# 1369   62.98    ...                  City            Public Safety
# 1370   53.16    ...                  City  Government Organization
# 1371   68.69    ...                  City                    Parks
# 1372   67.40    ...                  City                    Other
# 1373   72.39    ...                  City                  Transit
# 1374   58.94    ...                County                    Other
# 1375   74.16    ...                County            Public Safety
# 1376   47.21    ...                County            Public Safety
# 1377   78.38    ...                County            Public Safety
# 1378   33.33    ...                County  Government Organization
# 1379   64.17    ...      Special District            Public Safety
# 1380   66.81    ...      Special District            Public Safety
# 1381   75.17    ...      Special District            Public Safety
# 1382   71.09    ...      Special District            Public Safety
#
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ...         ...
# 1353        NaN
# 1354        NaN
# 1355        NaN
# 1356        NaN
# 1357        NaN
# 1358        NaN
# 1359        NaN
# 1360        NaN
# 1361        NaN
# 1362        NaN
# 1363        NaN
# 1364        NaN
# 1365        NaN
# 1366        NaN
# 1367  6200000.0
# 1368        NaN
# 1369  5300000.0
# 1370        NaN
# 1371        NaN
# 1372        NaN
# 1373        NaN
# 1374        NaN
# 1375        NaN
# 1376        NaN
# 1377        NaN
# 1378        NaN
# 1379        NaN
# 1380  2200000.0
# 1381        NaN
# 1382        NaN
#
# [1383 rows x 28 columns]

# %%
#Lets ensure that all the counties are represented in the data set
# %matplotlib inline
base = mergedmap.plot(color='black')
#looks good

# %%
base = mergedmap.plot(color='black',figsize=(15,13),edgecolor='black')
mergedmap.plot(ax=base, column='Election Results', cmap='Set2', categorical=True,legend = True)

# %%
#ok that is good, but it doesnt show us the intensity level of failures, and it is difficult to say why certain counties are green
# since all counties have experienced failures in the data set.
#Disclaimer: I used a pivot table in excel to find the % of failures
#in each county that have had measures fail.
faildata = 'https://github.com/nbennett4025/govproject/raw/master/countyballotfail.xlsx'
ballotfail = pd.read_excel(faildata,0)
ballotfail.head()
# Out:
#              County  failpercent
# 0             Adams     0.163265
# 1            Asotin     0.250000
# 2            Benton     0.235294
# 3  Benton, Franklin     1.000000
# 4            Chelan     0.384615

# %%
#ok lets merge and get our new map
mergedfailmap=countymap.merge(ballotfail, left_on='name', right_on='County')
mergedfailmap.head()
# Out:
#   countyfp     name                                           geometry  \
# 0      001    Adams  POLYGON ((-118.9825480580862 46.91134733328905...
# 1      003   Asotin  POLYGON ((-117.4196632992044 46.27754321148509...
# 2      005   Benton  POLYGON ((-119.8654444991138 46.12714840917387...
# 3      007   Chelan  POLYGON ((-120.9464421249536 47.47252236561713...
# 4      009  Clallam  POLYGON ((-123.5206495706549 48.22911230114539...
#
#     County  failpercent
# 0    Adams     0.163265
# 1   Asotin     0.250000
# 2   Benton     0.235294
# 3   Chelan     0.384615
# 4  Clallam     0.269231

# %%
base = mergedfailmap.plot(color='black', figsize=(20,13))
topLayer=mergedfailmap.plot(ax=base,column='failpercent',cmap='Reds',scheme='Quantiles',k=5,legend=True)
topLayer.set_title('Failure rate of government funding measures in Washington by County (2011-2017)',
                      color='black',fontdict={'fontsize':30})
plt.show()

# %% [markdown]
# This map of the % of ballot measures that fail does not show a clear regional pattern but it does hel us decontruct stereotypes about the state. While many assume that the easturn part of the state is more conservative and anti-government, there are many counties in Eastern Washington where ballot measures are more likely to pass than the liberal hubs of Western Washington.
#
# ## Conclusion
# While we are able to see clear differences in the performance of funding measures on ballots throughout the state, it is difficult from this data to explain differences in performance. Further research is required to build a workable model of what effects passage rates.
